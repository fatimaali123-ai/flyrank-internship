# %% [markdown]
# <a href="https://colab.research.google.com/github/fatimaali123-ai/flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fatimaali123-ai/flyrank-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My chosen lane is content ranking.
#
# Task type: Ranking
#
# The goal is to rank content items based on how likely they are to be useful and engaging for users.
#
# Instead of showing content using fixed rules, ML can learn patterns from user interactions and improve ranking decisions.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The ideal target is user satisfaction, but this is difficult to measure directly.
#
# A proxy target can be user engagement signals such as:
# - Click-through rate (CTR)
# - Watch time
# - Likes
# - Saves
# - Shares
#
# The model will predict the probability that a user will interact positively with a content item.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The success of the ranking system can be measured using:
#
# - NDCG (Normalized Discounted Cumulative Gain): measures how well the ranking order matches user preferences.
# - CTR improvement: measures whether users click recommended content more often.
#
# A good model should place the most relevant content higher in the ranking.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

data = {
    "user_id": [101,102,103,104],
    "content_id": ["A1","B2","C3","D4"],
    "category": ["AI","Sports","AI","News"],
    "views": [50,20,80,40],
    "likes": [10,2,25,8]
}

df = pd.DataFrame(data)

df
# Out:
#    user_id content_id category  views  likes
# 0      101         A1       AI     50     10
# 1      102         B2   Sports     20      2
# 2      103         C3       AI     80     25
# 3      104         D4     News     40      8

# %% [markdown]
# One row represents one user-content interaction.
#
# Each row describes how a specific user interacted with a specific content item.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# A fixed rule-based system may recommend content using simple conditions like showing the most viewed posts.
#
# However, users have different interests and preferences.
#
# ML can learn complex patterns from multiple signals such as user behavior, content features, and engagement history.
#
# This allows the system to personalize rankings instead of applying the same rule to everyone.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
