# %% [markdown]
# <a href="https://colab.research.google.com/github/fatimaali123-ai/flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fatimaali123-ai/flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My provisional lane is Content Performance Analysis.
#
# I chose this lane because businesses need to understand which types of content perform better in search results. By analyzing the available data, I hope to identify patterns that can support better content decisions. This project is intended to provide decision support rather than guarantee rankings.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research Question:
#
# Which content characteristics are associated with better search performance?
#
# Decision:
# Decide which type of content should be created or improved.
#
# Action:
# A content manager or SEO specialist can update existing pages or create new content based on the findings.
#
# Cost of a wrong recommendation:
# A wrong recommendation may waste time, effort, and marketing budget, and could lead to lower search visibility and fewer visitors.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !pwd
# !ls
# !find . -name "content_refresh_anonymized.csv"
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())
print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# /content/flyrank-internship
# AGENTS.md				    GUIDE.md	      scripts
# CLAUDE.md				    LICENSE	      SETUP.md
# Copy_of_02_your_first_readable_model.ipynb  notebooks	      skills
# data					    outputs	      submission
# DATA_USE.md				    README.md	      work
# docs					    requirements.txt
# ./data/raw/content_refresh_anonymized.csv
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project will identify observed patterns and relationships in the dataset that can support decision-making.
#
# The results can provide directional insights and decision support for improving content strategies.
#
# This project cannot prove causal relationships, cannot guarantee search ranking improvements, and cannot predict Google's ranking algorithm. The findings should be treated as helpful evidence rather than absolute predictions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
